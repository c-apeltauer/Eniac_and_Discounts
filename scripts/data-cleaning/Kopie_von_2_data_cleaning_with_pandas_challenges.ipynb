# %% [markdown]
# <a href="https://colab.research.google.com/github/c-apeltauer/Eniac_and_Discounts/blob/main/Kopie_von_2_data_cleaning_with_pandas_challenges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning with Pandas
#
# In this notebook we'll go through a few basic data cleaning steps that should be performed on all new datasets where necessary.
#
# We'll go through the process with both the `orders` and `orderlines` datasets. You can then practice these skills by cleaning the `products` dataset yourself

# %%
import pandas as pd

# %%
# orders.csv
url = "https://drive.google.com/file/d/1Vu0q91qZw6lqhIqbjoXYvYAQTmVHh6uZ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders = pd.read_csv(path)

# orderlines.csv
url = "https://drive.google.com/file/d/1FYhN_2AzTBFuWcfHaRuKcuCE6CWXsWtG/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orderlines = pd.read_csv(path)

# %% [markdown]
# Before we begin, let's create a copy of the `orders` and `orderlines` DataFrames. This way we are sure any of our changes won't affect the original DataFrames

# %%
orders_df = orders.copy()

# %%
orderlines_df = orderlines.copy()

# %% [markdown]
# One of the best ways to begin data cleaning is by exploring using `.info()`. This will tell us:
# * The shape of the DataFrame
# * The names of the columns
# * If there are any missing values
# * The datatypes of the columns
#
# By exploring the missing values and correcting any incorrect datatypes, we often come across inconsistencies in our data.
#
# Beyond this, we should also have a **check for any duplicate rows**.
#
# Let's first deal with the duplicates, as it's nice and easy, then we'll explore what `.info()` has to tell us.

# %% [markdown]
# ## 1.&nbsp; Duplicates
# We can check for duplicates using the pandas [.duplicated()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html) method.
#
# We can then delete these rows, if we wish, using [.drop_duplicates()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html)

# %%
# orders_df
orders_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# orderlines_df
orderlines_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# We have no duplicate rows in either DataFrame. Easy, there is no problem to solve. Normally though, if there were some duplicates, we'd drop the extra rows.

# %% [markdown]
# # 2.&nbsp; `.info()`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# * `total_paid` has 5 missing values
# * `created_date` should become datetime datatype

# %%
orderlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB

# %% [markdown]
# * `date` should be a datetime datatype
# * `unit_price` should be a float datatype

# %% [markdown]
# ## 3.&nbsp; Missing values

# %% [markdown]
# ### 3.1.&nbsp; Orders
# * `total_paid` has 5 missing values

# %%
num_missing = orders_df['total_paid'].isna().sum()
total_rows = orders_df.shape[0]
percent_missing = (100*num_missing/total_rows)
print(f"5 missing values represents {percent_missing:.5f}% of the rows in our DataFrame")
# Out:
# 5 missing values represents 0.00220% of the rows in our DataFrame

# %% [markdown]
# > A quick way to find out a percentage if you don't need to print out a sentence for yourself/students/colleagues is `.value_count(normalize=True)`

# %%
orders_df['total_paid'].isna().value_counts(normalize=True)
# Out:
# total_paid
# False    0.999978
# True     0.000022
# Name: proportion, dtype: float64

# %% [markdown]
# As there is such a tiny amount of missing values, we will simply delete these rows, as we have enough data without them.

# %%
orders_df = orders_df.dropna(axis=0)

# %% [markdown]
# Should you have a significant number of missing values in the future, you have a choice:
# + you can impute the values
# + you can take the values from other DataFrames if they are redundantly stored
# + you can delete the rows or columns
# + or any number of other creative solutions
#
# Please, always consider how much time you have on your project, and what impact your method of choice will have on your final assesment.

# %% [markdown]
# ### 3.2.&nbsp; Orderlines
# There are no missing values in `orderlines_df`

# %% [markdown]
# ## 4.&nbsp; Datatypes

# %% [markdown]
# ### 4.1.&nbsp; Orders
# * `created_date` should become datetime datatype

# %%
orders_df["created_date"] = pd.to_datetime(orders_df["created_date"])
# Out:
# <ipython-input-12-87c26cc5d8b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_df["created_date"] = pd.to_datetime(orders_df["created_date"])

# %% [markdown]
# ### 4.1.&nbsp; Orderlines
# * `date` should be a datetime datatype
# * `unit_price` should be a float datatype

# %% [markdown]
# #### 4.1.1.&nbsp; `date`

# %%
orderlines_df["date"] = pd.to_datetime(orderlines_df["date"])

# %% [markdown]
# #### 4.1.2.&nbsp;`unit_price`

# %%
#orderlines_df["unit_price"] = pd.to_numeric(orderlines_df["unit_price"])

# %% [markdown]
# As you can see when we try to convert `unit_price` to a numerical datatype, we receive a `ValueError` telling us that pandas doesn't understand the number `1.137.99`. This is probably because numbers cannot have multiple decimal points. Let's see if there are any other numbers like this:
#
# > `.` is a wildcard in regex, we need the `\` as an escape

# %%
# Count the number of decimal points in the unit_price
orderlines_df['unit_price'].str.count("\.").value_counts()
# Out:
# unit_price
# 1    257814
# 2     36169
# Name: count, dtype: int64

# %%
orderlines_df['unit_price'].str.count("\d{1,2}\.\d{3,3}\.\d{2,2}").value_counts()
# Out:
# unit_price
# 0    257814
# 1     36169
# Name: count, dtype: int64

# %%
orderlines_df[orderlines_df['unit_price'].str.contains("\d{1,2}\.\d{3,3}\.\d{2,2}")]
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 6       1119115    299544           0                 1  APP1582   1.137.99
# 11      1119126    299549           0                 1  PAC0929   2.565.99
# 15      1119131    299553           0                 1  APP1854   3.278.99
# 43      1119195    299582           0                 1  PAC0961   2.616.99
# 59      1119214    299596           0                 1  PAC1599   2.873.99
# ...         ...       ...         ...               ...      ...        ...
# 293862  1649999    452946           0                 1  APP2075   2.999.00
# 293887  1650045    527321           0                 1  PAC2148   3.497.00
# 293889  1650050    527324           0                 1  PAC2117   3.075.00
# 293911  1650088    527342           0                 1  APP2492   1.329.00
# 293936  1650135    527364           0                 1  APP2491   1.329.00
#
#                       date
# 6      2017-01-01 01:17:21
# 11     2017-01-01 02:07:42
# 15     2017-01-01 02:14:47
# 43     2017-01-01 08:54:00
# 59     2017-01-01 09:53:11
# ...                    ...
# 293862 2018-03-14 13:03:33
# 293887 2018-03-14 13:10:15
# 293889 2018-03-14 13:10:56
# 293911 2018-03-14 13:24:51
# 293936 2018-03-14 13:36:13
#
# [36169 rows x 7 columns]

# %% [markdown]
# Looks like over 36000 rows in `orderlines` are affected by this problem. Let's work out how much that is as a percentage of our total data.

# %%
# Count the rows with more than one `.`
mult_decimal_rows = (orderlines_df['unit_price'].str.count("\.")>1).sum()

# Find the percentage of corrupted rows
percent_corrupted = (100 * mult_decimal_rows / orderlines_df.shape[0])
print(f"{percent_corrupted:.2f}% of the rows in our DataFrame have multiple decimal points in the unit_price")
# Out:
# 12.30% of the rows in our DataFrame have multiple decimal points in the unit_price

# %% [markdown]
# This is a bit of a tricky decision as 12.3% is a significant amount of our data... and we might even end up losing a larger portion of our data than this too. For the moment we will delete the rows as we only have 2 weeks for this project and I'd like some quick, accurate results to show. If we have time at the end, we can come back and investigate this problem further, maybe there's a solution?
#
# Each row of `orderlines` represents a product in an order. For example, if order number 175 contained 3 seperate products, then order 175 would have 3 rows in `orderlines`, one row for each of the products. If 2 of those products have 'normal' prices (14.99, 15.85) and 1 has a price with 2 decimal points (1.137.99), we need to remove the whole order and not just the affected row. If we only remove the row with 2 decimal places then any later analysis about products and prices could be misleading.
#
# We therefore need to find the order numbers associated with the rows that have 2 decimal points, and then remove all the associated rows.

# %%
# Boolean mask to find the orders that contain a price with multiple decimal points
#multiple_decimal_mask = orderlines_df['unit_price'].str.count("\.") > 1

# Apply the boolean mask to the orderlines DataFrame. This way we can find the order_id of all the affected orders.
#corrupted_order_ids = orderlines_df.loc[multiple_decimal_mask, "id_order"]

# Keep only the rows that do not have multiple decimal points
#orderlines_df = orderlines_df.loc[~orderlines_df['id_order'].isin(corrupted_order_ids)]

# %%
orderlines_df.shape[0]
# Out:
# 293983

# %% [markdown]
# We still have 216250 rows in orderlines to work with. This should be more than enough for our evaluation.
#
# Now that all of the 2 decimal point prices have been removed, let's try again to convert the column `unit_price` to the correct datatype.

# %%
orderlines_df['unit_price'] = orderlines_df['unit_price'].astype(str).apply(lambda x: x.replace('.','',1) if x.count('.')>1 else x) #removes first decimal point
orderlines_df["unit_price"] = pd.to_numeric(orderlines_df["unit_price"])

# %% [markdown]
# It worked perfectly

# %% [markdown]
# # Challenge: Clean the `products` DataFrame
# Now it's your turn. Use the lessons you learnt above and clean the products DataFrame. You don't have to copy exactly what we did. Think about the consequences of your actions, sometimes it is ok to delete rows, other times you may wish to come up with more creative solutions.

# %%
# products.csv
url = "https://drive.google.com/file/d/1afxwDXfl-7cQ_qLwyDitfcCx3u7WMvkU/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products = pd.read_csv(path)

# %%
# your code here
products_df = products.copy()
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                                 mouse Apple USB cable.     59     569.898
# 3                  IPhone dock and USB Cable Apple iPod.     25     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
#        in_stock      type
# 0             1      8696
# 1             0  13855401
# 2             0      1387
# 3             0      1230
# 4             1      1364
# ...         ...       ...
# 19321         1     12282
# 19322         1      1392
# 19323         1      1392
# 19324         0      1392
# 19325         1      1392
#
# [19326 rows x 7 columns]

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Look for Duplicates

# %%
products_df.duplicated().sum()
# Out:
# np.int64(8746)

# %%
products_df = products_df.drop_duplicates()
products_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Look for Missing values

# %%
# your code here
products_df.isna().sum()
# Out:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %%
# Replace missing desc with empty strings
products_df.loc[:, 'desc'] = products_df.loc[:, 'desc'].fillna('')
products_df.isna().sum()
# Out:
# sku             0
# name            0
# desc            0
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %%
products_df[products_df.loc[:, 'type'].isna()]
# Out:
#              sku                                               name  \
# 307      SAN0017       SanDisk Cruzer Edge USB 2.0 Flash Drive 16GB
# 530      SAN0026    SanDisk Extreme Cruzer 16GB USB 3.0 Flash Drive
# 792      APP0672                    Apple iPhone 5S 16GB Space Gray
# 797      APP0673                        Apple iPhone 5S 16GB Silver
# 798      APP0675                    Apple iPhone 5S 32GB Space Gray
# 1193     APP0823                         Apple iPhone 6 16GB Silver
# 1199     APP0829                    Apple iPhone 6 Plus 16GB Silver
# 1200     APP0822                     Apple iPhone 6 16GB Space Gray
# 1201     APP0825                     Apple iPhone 6 64GB Space Gray
# 1202     APP0826                         Apple iPhone 6 64GB Silver
# 1203     APP0828                Apple iPhone 6 Plus 16GB Space Gray
# 1280     APP0856                          Apple iPhone 6 128GB Gold
# 1281     APP0857                Apple iPhone 6 Plus 64GB Space Gray
# 1282     APP0858                    Apple iPhone 6 Plus 64GB Silver
# 1283     APP0860               Apple iPhone 6 Plus 128GB Space Gray
# 1759     PAC0602               Pack Synology DS1815 + + 40TB WD Red
# 1899     SAN0035       SanDisk Ultra 16GB SDHC Memory Card Class 10
# 3016     APP1166                        Apple iPhone 6S 16GB Silver
# 3055     ELG0014                           Elgato Video Capture Mac
# 3090     APP1185                Apple iPhone 6S Plus 64GB Rose Gold
# 3106     APP1167                    Apple iPhone 6S 16GB Space Gray
# 3107     APP1169                     16GB Apple iPhone 6S Rose Gold
# 3108     APP1170                        Apple iPhone 6S 64GB Silver
# 3110     APP1171                    Apple iPhone 6S 64GB Space Gray
# 3112     APP1172                          Apple iPhone 6S 64GB Gold
# 3114     APP1173                     64GB Apple iPhone 6S Rose Gold
# 3116     APP1178                   Apple iPhone 6S Plus 16GB Silver
# 3117     APP1179               Apple iPhone 6S Plus 16GB Space Gray
# 3118     APP1180                     Apple iPhone 6S Plus 16GB Gold
# 3119     APP1181                Apple iPhone 6S Plus 16GB Rose Gold
# 3120     APP1182                   Apple iPhone 6S Plus 64GB Silver
# 3121     APP1183               Apple iPhone 6S Plus 64GB Space Gray
# 3122     APP1184                     Apple iPhone 6S Plus 64GB Gold
# 3123     APP1186                  Apple iPhone 6s Plus 128GB Silver
# 3124     APP1187              Apple iPhone 6s Plus 128GB Space Gray
# 3125     APP1188                    Apple iPhone 6s Plus 128GB Gold
# 3126     APP1189               Apple iPhone 6s Plus 128GB Rose Gold
# 3138     APP1168                          Apple iPhone 6S 16GB Gold
# 10864    APP1202                    Apple iPad Wi-Fi 32GB Pro Plata
# 11766    APP1478                           Apple iPhone 16GB Silver
# 11767    APP1479                             Apple iPhone 16GB Gold
# 11768    APP1480                        Apple iPhone 16GB Rose Gold
# 11770    APP1482                           Apple iPhone 64GB Silver
# 11771    APP1483                             Apple iPhone 64GB Gold
# 15932    PAC2056  Second hand - Apple Mac mini Core 2 Duo 226Ghz...
# 18741  GTE0093-A  Open - G-Technology G-DRIVE HDD 7200rpm 4TB Th...
# 18822    DOD0010   Dodocool Sports Wireless Stereo Headphones Black
# 18838    CAL0010  Station 3 Caldigit Thunderbolt Thunderbolt out...
# 19092  SYN0173-A      Open - Synology DS218 + NAS server Mac and PC
# 19185    RIN0017                                    Chime Bell Ring
#
#                                                     desc      price  \
# 307                         Pendrive USB 2.0 Mac and PC.          8
# 530             USB 3.0 flash drive 16GB USB Mac and PC.         22
# 792               New iPhone 5S 16G Libre (ME432Y / AB).  4.694.994
# 797                New Free iPhone 5S 16GB (ME433Y / A).  4.090.042
# 798                New Free iPhone 5S 32GB (ME435Y / A).        559
# 1193               New iPhone 6 16GB Free (MG482QL / A).        639
# 1199           New iPhone 6 Plus 16G Free (MGA92QL / A).        749
# 1200               New iPhone 6 16GB Free (MG472QL / A).        639
# 1201               New iPhone 6 64GB Free (MG4F2QL / A).        749
# 1202               New iPhone 6 64GB Free (MG4H2QL / A).        749
# 1203          New 16GB iPhone 6 Plus Free (MGA82QL / A).        749
# 1280              New Free iPhone 6 128GB (MG4E2QL / A).        899
# 1281          New iPhone 6 Plus 64GB Free (MGAH2QL / A).        859
# 1282          New 64GB iPhone 6 Plus Free (MGAJ2QL / A).        859
# 1283             iPhone 6 Plus 128GB Free (MGAC2QL / A).        999
# 1759               Pack Synology DS1815 + + 40TB WD Red.    3059.99
# 1899                              16GB SDHC memory card.         14
# 3016                           New 16GB iPhone 6S Libre.        749
# 3055             Mac USB analog video recorder hardware.      99.95
# 3090                       New iPhone 6S Plus 64GB Free.        969
# 3106                           New 16GB iPhone 6S Libre.        749
# 3107                           New 16GB iPhone 6S Libre.        749
# 3108                           New 64GB iPhone 6S Libre.        859
# 3110                           New 64GB iPhone 6S Libre.        859
# 3112                           New 64GB iPhone 6S Libre.        859
# 3114                           New 64GB iPhone 6S Libre.        859
# 3116                       New iPhone 6S Plus 16GB Free.        859
# 3117                       New iPhone 6S Plus 16GB Free.        859
# 3118                       New iPhone 6S Plus 16GB Free.        859
# 3119                       New iPhone 6S Plus 16GB Free.        859
# 3120                       New iPhone 6S Plus 64GB Free.        969
# 3121                       New iPhone 6S Plus 64GB Free.        969
# 3122                       New iPhone 6S Plus 64GB Free.        969
# 3123                     New iPhone 6s Plus 128GB Libre.        749
# 3124                     New iPhone 6s Plus 128GB Libre.        749
# 3125                     New iPhone 6s Plus 128GB Libre.        749
# 3126                     New iPhone 6s Plus 128GB Libre.        749
# 3138                           New 16GB iPhone 6S Libre.        749
# 10864                           Pro New iPad 32GB Wi-Fi.        899
# 11766               New iPhone SE with 4 inch 16GB free.        489
# 11767               New iPhone SE with 4 inch 16GB free.        489
# 11768               New iPhone SE with 4 inch 16GB free.        489
# 11770       New iPhone SE with 4-inch screen 64 free GB.        549
# 11771       New iPhone SE with 4-inch screen 64 free GB.        549
# 15932  Computer Refurbished Mac mini Core i2 226GHz |...        599
# 18741  Hard disk refitted with 2 USB 3 and Thunderbol...     423.99
# 18822  Wireless stereo headphones with remote control...      24.99
# 18838  Thunderbolt external box 3 to magnify your tea...  2.999.905
# 19092  NAS server storage refitted comprehensive spec...     344.99
# 19185  Chime bell with free Wi-Fi to amplify your not...    350.005
#
#       promo_price  in_stock type
# 307        59.895         0  NaN
# 530       209.935         0  NaN
# 792     4.694.994         0  NaN
# 797     4.090.042         0  NaN
# 798     3.989.975         0  NaN
# 1193      639.001         0  NaN
# 1199    7.490.021         0  NaN
# 1200      639.001         0  NaN
# 1201    7.490.021         0  NaN
# 1202    7.503.331         0  NaN
# 1203    7.490.021         0  NaN
# 1280    8.989.937         0  NaN
# 1281    8.590.032         0  NaN
# 1282    8.590.032         0  NaN
# 1283    7.999.915         0  NaN
# 1759      2560.99         0  NaN
# 1899       70.906         0  NaN
# 3016    7.489.997         0  NaN
# 3055      969.936         0  NaN
# 3090    9.689.995         0  NaN
# 3106    7.489.997         0  NaN
# 3107    7.489.997         0  NaN
# 3108    8.589.996         0  NaN
# 3110    8.603.306         0  NaN
# 3112    8.589.996         0  NaN
# 3114    8.589.996         0  NaN
# 3116    8.589.996         0  NaN
# 3117    8.589.996         0  NaN
# 3118    8.589.996         0  NaN
# 3119    8.589.996         0  NaN
# 3120    9.689.995         0  NaN
# 3121    9.689.995         0  NaN
# 3122    9.689.995         0  NaN
# 3123    7.340.005         0  NaN
# 3124    7.340.005         0  NaN
# 3125    7.340.005         0  NaN
# 3126    7.340.005         0  NaN
# 3138    7.489.997         0  NaN
# 10864   9.028.113         0  NaN
# 11766   4.903.307         0  NaN
# 11767   4.903.307         0  NaN
# 11768   4.903.307         0  NaN
# 11770     550.331         0  NaN
# 11771     550.331         0  NaN
# 15932         329         0  NaN
# 18741   2.923.459         0  NaN
# 18822     219.899         1  NaN
# 18838   2.999.905         1  NaN
# 19092   3.309.166         0  NaN
# 19185     350.005         0  NaN

# %%
products_df[products_df.loc[:, 'type'] == '0']
# Out:
# Empty DataFrame
# Columns: [sku, name, desc, price, promo_price, in_stock, type]
# Index: []

# %%
# Replace na types with '0' (not in use otherwise)
products_df.loc[:, 'type'] = products_df.loc[:, 'type'].fillna('0')
products_df.isna().sum()
# Out:
# sku             0
# name            0
# desc            0
# price          46
# promo_price     0
# in_stock        0
# type            0
# dtype: int64

# %% [markdown]
# ### Check / Change Data types

# %%
# your code here
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10580 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10580 non-null  object
#  1   name         10580 non-null  object
#  2   desc         10580 non-null  object
#  3   price        10534 non-null  object
#  4   promo_price  10580 non-null  object
#  5   in_stock     10580 non-null  int64
#  6   type         10580 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 661.2+ KB

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                                 mouse Apple USB cable.     59     569.898
# 3                  IPhone dock and USB Cable Apple iPod.     25     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
#        in_stock      type
# 0             1      8696
# 1             0  13855401
# 2             0      1387
# 3             0      1230
# 4             1      1364
# ...         ...       ...
# 19321         1     12282
# 19322         1      1392
# 19323         1      1392
# 19324         0      1392
# 19325         1      1392
#
# [10580 rows x 7 columns]

# %%
# Make in_stock boolean
products_df.loc[:, 'in_stock'] = pd.to_numeric(products_df.loc[:, 'in_stock'])
products_df.loc[:, 'in_stock'] = products_df.loc[:, 'in_stock'].astype(bool)
products_df
# Out:
# <ipython-input-35-f34a6c473492>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ True False False ...  True False  True]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   products_df.loc[:, 'in_stock'] = products_df.loc[:, 'in_stock'].astype(bool)
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                                 mouse Apple USB cable.     59     569.898
# 3                  IPhone dock and USB Cable Apple iPod.     25     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
#        in_stock      type
# 0          True      8696
# 1         False  13855401
# 2         False      1387
# 3         False      1230
# 4          True      1364
# ...         ...       ...
# 19321      True     12282
# 19322      True      1392
# 19323      True      1392
# 19324     False      1392
# 19325      True      1392
#
# [10580 rows x 7 columns]

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10580 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10580 non-null  object
#  1   name         10580 non-null  object
#  2   desc         10580 non-null  object
#  3   price        10534 non-null  object
#  4   promo_price  10580 non-null  object
#  5   in_stock     10580 non-null  bool
#  6   type         10580 non-null  object
# dtypes: bool(1), object(6)
# memory usage: 588.9+ KB

# %%
# make type numerical
products_df.loc[:, 'type'] = products_df.loc[:, 'type'].str.replace(',', '.')
#products_df.info()

# %%
products_df['type'] = products_df.loc[:, 'type'].astype(float)
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB
# <ipython-input-38-c6883cd28c4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_df['type'] = products_df.loc[:, 'type'].astype(float)

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                                 mouse Apple USB cable.     59     569.898
# 3                  IPhone dock and USB Cable Apple iPod.     25     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
#        in_stock        type
# 0          True      8696.0
# 1         False  13855401.0
# 2         False      1387.0
# 3         False      1230.0
# 4          True      1364.0
# ...         ...         ...
# 19321      True     12282.0
# 19322      True      1392.0
# 19323      True      1392.0
# 19324     False      1392.0
# 19325      True      1392.0
#
# [10580 rows x 7 columns]

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10580 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10580 non-null  object
#  1   name         10580 non-null  object
#  2   desc         10580 non-null  object
#  3   price        10534 non-null  object
#  4   promo_price  10580 non-null  object
#  5   in_stock     10580 non-null  bool
#  6   type         10580 non-null  float64
# dtypes: bool(1), float64(1), object(5)
# memory usage: 588.9+ KB

# %%
products_df['type'] = products_df.loc[:, 'type'].astype(int)
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10580 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10580 non-null  object
#  1   name         10580 non-null  object
#  2   desc         10580 non-null  object
#  3   price        10534 non-null  object
#  4   promo_price  10580 non-null  object
#  5   in_stock     10580 non-null  bool
#  6   type         10580 non-null  int64
# dtypes: bool(1), int64(1), object(5)
# memory usage: 588.9+ KB
# <ipython-input-41-c61ef9787496>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_df['type'] = products_df.loc[:, 'type'].astype(int)

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                                 mouse Apple USB cable.     59     569.898
# 3                  IPhone dock and USB Cable Apple iPod.     25     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
#        in_stock      type
# 0          True      8696
# 1         False  13855401
# 2         False      1387
# 3         False      1230
# 4          True      1364
# ...         ...       ...
# 19321      True     12282
# 19322      True      1392
# 19323      True      1392
# 19324     False      1392
# 19325      True      1392
#
# [10580 rows x 7 columns]

# %%
products_df.loc[products_df.loc[:, 'type'] > 1E+11]
# Out:
#            sku                                               name  \
# 25     MOP0011  Mophie Juice Pack Air Battery Case iPhone 4 / ...
# 58     MOP0013  Mophie Juice Pack Air Battery Case iPhone 4 / ...
# 362    REP0043                      Speaker lower repair iPhone 4
# 369    REP0036                        Full screen repair iPhone 4
# 370    REP0040                        Home button repair iPhone 4
# ...        ...                                                ...
# 19315  REP0413                            repair rear camera iPad
# 19316  REP0407                                iPad battery repair
# 19317  REP0403                             iPad LCD screen repair
# 19318  REP0402                           iPad touch screen repair
# 19320  REP0076           repair Full screen iPad (1st generation)
#
#                                                     desc      price  \
# 25             Battery Case iPhone 4 / 4S rigid polymer.      69.99
# 58         Case Battery (1500mAh) iPhone 4 / 4S polymer.      69.95
# 362    Repair service including parts and labor for i...    499.004
# 369    Repair service including parts and labor for i...      49.99
# 370    Repair service including parts and labor for i...      49.99
# ...                                                  ...        ...
# 19315  Repair service including parts and labor for iPad  6.999.003
# 19316  Repair service including parts and labor for iPad  6.999.003
# 19317  Repair service including parts and labor for iPad     159.99
# 19318  Repair service including parts and labor for iPad     139.99
# 19320  Repair service including parts and labor for iPad     149.99
#
#       promo_price  in_stock          type
# 25         56.991     False  549000000000
# 58        539.902     False  549000000000
# 362       499.004     False  144000000000
# 369       499.899     False  144000000000
# 370       499.899     False  144000000000
# ...           ...       ...           ...
# 19315       69.99     False  144000000000
# 19316       69.99     False  144000000000
# 19317   1.599.898     False  144000000000
# 19318   1.399.897     False  144000000000
# 19320   1.499.795     False  144000000000
#
# [846 rows x 7 columns]

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10580 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10580 non-null  object
#  1   name         10580 non-null  object
#  2   desc         10580 non-null  object
#  3   price        10534 non-null  object
#  4   promo_price  10580 non-null  object
#  5   in_stock     10580 non-null  bool
#  6   type         10580 non-null  int64
# dtypes: bool(1), int64(1), object(5)
# memory usage: 588.9+ KB

# %%
products_df.isna().sum()
# Out:
# sku             0
# name            0
# desc            0
# price          46
# promo_price     0
# in_stock        0
# type            0
# dtype: int64

# %%
#products_df = products_df.set_index('sku')
#products_df

# %%
#find missing prices in products
products_missing_price = products_df.loc[products_df['price'].isna(),:]
products_missing_price
# Out:
#              sku                                               name  \
# 34       TWS0019  Twelve South MagicWand support Apple Magic Tra...
# 1900     AII0008           Aiino Case MacBook Air 11 '' Transparent
# 2039     CEL0020  Celly Ambo Luxury Leather Case + iPhone 6 Case...
# 2042     CEL0007  Celly Wallet Case with removable cover Black i...
# 2043     CEL0012            Celly Silicone Hard Shell iPhone 6 Blue
# 2044     CEL0014        Celly Silicone Hard Shell iPhone 6 Amarillo
# 2049     CEL0015    Celly fur-lined Powerbank battery 4000mAh Black
# 2051     CEL0018     Celly Wallet Leather Case cover Black iPhone 6
# 2052     CEL0023  Celly Ambo Luxury Leather Case + Case Gold iPh...
# 2053     CEL0025  Celly Ambo Luxury Leather Case + Case iPhone 6...
# 8000     APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display...
# 12052    CEL0028  Celly Swing Arm button selfie with Bluetooth B...
# 12053    CEL0029  Celly extensible arm selfie with Bluetooth but...
# 12054    CEL0030  Celly Smart Drive Housing + clip car holder iP...
# 12055    CEL0031  Celly Smart Drive Case + Car clip support iPho...
# 12059    CEL0032      Celly Gost clamp fixing car + Magnetica Black
# 12060    CEL0042  Celly iPhone Case Fluor 6s / 6 Black / Transpa...
# 12061    CEL0043  Celly Fluor Case iPhone 6 / 6S Pink / Transparent
# 12062    CEL0044  Celly iPhone Case Fluor 6s / 6 Yellow / Transp...
# 12064    CEL0038           Celly Frost Cover for iPhone 6 / 6S Rosa
# 12067    CEL0033  Celly Waterproof iPad Case / Air / Pro 97 "Tra...
# 12068    CEL0034  Celly Ambo cover with lid iPhone 6 / 6S Plus B...
# 12069    CEL0035  Celly Ambo cover with lid iPhone 6 / 6S Plus B...
# 12070    CEL0036  Celly Adapter Micro USB connector to Lightning...
# 12071    CEL0051   Celly 4000mAh Battery Power Bank Aluminum Dorado
# 12072    CEL0052   Celly 4000mAh Battery Power Bank Aluminum Silver
# 12073    CEL0053             Celly IceCube Case iPhone 6 / 6S Black
# 12074    CEL0054              Celly IceCube Case iPhone 6 / 6S Rosa
# 12075    CEL0055             Celly IceCube Case iPhone 6 / 6S White
# 12076    CEL0056          IceCube Celly iPhone Case 6 / 6s Amarillo
# 12077    CEL0057        Celly IceCube Case iPhone 6 / 6S Plus Black
# 12078    CEL0058         Celly IceCube Case iPhone 6 / 6S Plus Rosa
# 12079    CEL0059        Celly IceCube Case iPhone 6 / 6S Plus White
# 12080    CEL0060     Celly IceCube Case iPhone 6 / 6S Plus Amarillo
# 12088    CEL0040     Celly Frost Cover for iPhone 6 / 6S Plus White
# 12089    CEL0041              Celly iPhone 6S Plus Frost Case Black
# 12092    CEL0045         Laser Case Celly iPhone 6 / 6S Dark Silver
# 12093    CEL0046        Laser Case Celly iPhone 6 / 6S Clear Silver
# 12095    CEL0047              Laser Case Celly iPhone 6 / 6S Dorado
# 12096    CEL0048                Laser Case Celly iPhone 6 / 6S Rosa
# 12097    CEL0049         Laser Case Celly iPhone 6 / 6S Plus Dorado
# 12098    CEL0050   Laser Case Celly iPhone 6 / 6S Plus Silver Clear
# 12100    CEL0037          Celly Frost Cover for iPhone 6 / 6S Black
# 12238    CEL0027          Celly Frost Cover for iPhone 6 / 6S White
# 12242    CEL0039       Celly Frost Cover for iPhone 6 / 6S Amarillo
# 12947  CEL0034-A    (Open) Celly iPhone 6S Plus Housing Frost White
#
#                                                     desc price promo_price  \
# 34     MagicWand for wireless keyboard and Magic Trac...   NaN     299.899
# 1900       MacBook Air 11-inch casing with matte finish.   NaN       22.99
# 2039   Cover and housing together with magnet for iPh...   NaN     399.905
# 2042              Case Book for iPhone 6 card case type.   NaN     128.998
# 2043                       Hard Shell Silicone iPhone 6.   NaN        4.99
# 2044                       Hard Shell Silicone iPhone 6.   NaN      59.895
# 2049   Leather-wrapped External Battery 4000mAh for i...   NaN     239.895
# 2051   Card case with transparent protective cover fo...   NaN     294.877
# 2052   Cover and housing together with magnet for iPh...   NaN     329.894
# 2053   Cover and housing together with magnet for iPh...   NaN     449.878
# 8000   Desktop Apple iMac 21.5 inch i5 31 GHz Retina ...   NaN     1305.59
# 12052                   selfie extendable arm for iPhone   NaN      59.895
# 12053                   selfie extendable arm for iPhone   NaN      69.902
# 12054  Magnetic holder for car Compatible iPhone 5 5s...   NaN      89.903
# 12055  Magnetic car holder compatible with iPhone 6 / 6S   NaN     149.895
# 12059     Magnetic holder for car Compatible with iPhone   NaN     119.899
# 12060                Protective Case for iPhone 6 and 6s   NaN      99.898
# 12061                Protective Case for iPhone 6 and 6s   NaN      99.898
# 12062  protective case with two colors for iPhone 6 a...   NaN      79.896
# 12064                Ultra Thin Case for iPhone 6 and 6s   NaN      89.903
# 12067  waterproof protective case for iPad bag format...   NaN     149.895
# 12068  Imiatación cover skin with removable lid for i...   NaN     199.904
# 12069  Imiatación cover skin with removable lid for i...   NaN     199.904
# 12070       Micro USB adapter cable connection Lightning   NaN      89.903
# 12071  external battery capacity 4000mAh output volta...   NaN     129.894
# 12072  external battery capacity 4000mAh output volta...   NaN     199.892
# 12073                  Anti-shock Case for iPhone 6 / 6S   NaN     169.884
# 12074                  Anti-shock Case for iPhone 6 / 6S   NaN      99.898
# 12075                  Anti-shock Case for iPhone 6 / 6S   NaN     119.899
# 12076                  Anti-shock Case for iPhone 6 / 6S   NaN     119.899
# 12077             Anti-shock Case for iPhone 6 / 6S Plus   NaN     169.896
# 12078             Anti-shock Case for iPhone 6 / 6S Plus   NaN      99.898
# 12079             Anti-shock Case for iPhone 6 / 6S Plus   NaN     119.899
# 12080             Anti-shock Case for iPhone 6 / 6S Plus   NaN     169.896
# 12088           Ultra Thin Case for iPhone 6 and 6s Plus   NaN      89.903
# 12089                Ultra Thin Case for iPhone 6 and 6s   NaN      89.903
# 12092                Protective Case for iPhone 6 and 6s   NaN     149.895
# 12093                Protective Case for iPhone 6 and 6s   NaN     149.895
# 12095                Protective Case for iPhone 6 and 6s   NaN     149.895
# 12096                Protective Case for iPhone 6 and 6s   NaN     149.895
# 12097      Protective Case for iPhone 6 Plus and 6s Plus   NaN     149.895
# 12098      Protective Case for iPhone 6 Plus and 6s Plus   NaN     149.895
# 12100                Ultra Thin Case for iPhone 6 and 6s   NaN      99.898
# 12238           Flexible plastic shell for iPhone 6 / 6S   NaN      89.903
# 12242                Ultra Thin Case for iPhone 6 and 6s   NaN      89.903
# 12947           Ultra Thin Case for iPhone 6 and 6s Plus   NaN      74.893
#
#        in_stock      type
# 34        False      8696
# 1900      False  13835403
# 2039      False  11865403
# 2042      False  11865403
# 2043      False  11865403
# 2044      False  11865403
# 2049      False      1515
# 2051      False  11865403
# 2052      False  11865403
# 2053      False  11865403
# 8000      False      1282
# 12052     False  11905404
# 12053     False      5720
# 12054     False      5720
# 12055     False      5720
# 12059     False  12285400
# 12060     False  11865403
# 12061     False  11865403
# 12062      True  11865403
# 12064     False  11865403
# 12067     False  12635403
# 12068     False  11865403
# 12069     False  11865403
# 12070      True  14365395
# 12071     False      1515
# 12072     False      1515
# 12073     False  11865403
# 12074     False  11865403
# 12075     False  11865403
# 12076     False  11865403
# 12077     False      5403
# 12078     False  11865403
# 12079     False  11865403
# 12080     False  11865403
# 12088     False  11865403
# 12089     False  11865403
# 12092     False  11865403
# 12093     False  11865403
# 12095     False  11865403
# 12096     False  11865403
# 12097     False  11865403
# 12098     False  11865403
# 12100     False  11865403
# 12238     False  11865403
# 12242     False  11865403
# 12947     False      1298

# %%
#find sku prices in the orderlines df
sku_prices_match =orderlines_df.loc[orderlines_df['sku'].isin(products_missing_price['sku'])]
#find the mean of the prices
reconstructed_prices = sku_prices_match.groupby('sku')['unit_price'].mean().round(2)
reconstructed_prices = reconstructed_prices.reset_index()

# %%
for index, row in reconstructed_prices.iterrows():
  sku = row['sku']
  price = row['unit_price']
  products_df.loc[products_df['sku'] == sku, 'price'] = str(price)

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10580 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10580 non-null  object
#  1   name         10580 non-null  object
#  2   desc         10580 non-null  object
#  3   price        10558 non-null  object
#  4   promo_price  10580 non-null  object
#  5   in_stock     10580 non-null  bool
#  6   type         10580 non-null  int64
# dtypes: bool(1), int64(1), object(5)
# memory usage: 588.9+ KB

# %%
# Still 22 missing
# drop them
products_df = products_df.dropna(axis=0)
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10558 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10558 non-null  object
#  1   name         10558 non-null  object
#  2   desc         10558 non-null  object
#  3   price        10558 non-null  object
#  4   promo_price  10558 non-null  object
#  5   in_stock     10558 non-null  bool
#  6   type         10558 non-null  int64
# dtypes: bool(1), int64(1), object(5)
# memory usage: 587.7+ KB

# %%
products_df.loc[:, 'price'].str.contains("^\d{3,3}\.\d{3,3}$").value_counts()
# Out:
# price
# False    10419
# True       139
# Name: count, dtype: int64

# %%
products_df.isna().sum()
# Out:
# sku            0
# name           0
# desc           0
# price          0
# promo_price    0
# in_stock       0
# type           0
# dtype: int64

# %%
products_df.loc[products_df.loc[:, 'price'].str.contains("^\d{3,3}\.\d{3,3}$")]
# Out:
#              sku                                               name  \
# 362      REP0043                      Speaker lower repair iPhone 4
# 515      SEN0061  Sennheiser EZX 80 Handsfree iPhone iPad and iP...
# 518      SEV0026  Service installation RAM + HDD + SSD MacBook /...
# 525      SEV0024      Service installation RAM + HDD + SSD Mac mini
# 526      SEV0025          Service installation RAM + HDD + SSD iMac
# ...          ...                                                ...
# 19093    ELG0037           Elgato Eve Wireless Sensor Room Interior
# 19162  FIB0002-A        Open - Fibaro HomeKitt Sensor Door / Window
# 19185    RIN0017                                    Chime Bell Ring
# 19298    REP0428                      iPhone Speaker lower repair 7
# 19306    REP0429                 iPhone Speaker lower repair 7 plus
#
#                                                     desc    price promo_price  \
# 362    Repair service including parts and labor for i...  499.004     499.004
# 515    IPhone bluetooth headset with microphone iPad ...  649.891     649.891
# 518    RAM + HDD installation + SSD in your MacBook /...  599.918     599.918
# 525    installation RAM HDD + SSD + on your Mac mini ...  599.918     599.918
# 526    installation RAM HDD + SSD + on your iMac + Da...  599.918     599.918
# ...                                                  ...      ...         ...
# 19093  Sensor air quality temperature and humidity fo...  799.931     799.931
# 19162  Sensor refurbished multi-functions for doors a...  599.918     501.067
# 19185  Chime bell with free Wi-Fi to amplify your not...  350.005     350.005
# 19298  Repair service including parts and labor for i...  599.906     599.906
# 19306  Repair service including parts and labor for i...  599.906     599.906
#
#        in_stock          type
# 362       False  144000000000
# 515       False          5384
# 518       False      20642062
# 525       False      20642062
# 526       False      20642062
# ...         ...           ...
# 19093      True      11905404
# 19162     False         11859
# 19185     False             0
# 19298     False  144000000000
# 19306     False  144000000000
#
# [139 rows x 7 columns]

# %%
products_df.loc[products_df.loc[:, 'price'].str.contains("^\d+\.\d{3,3}\.\d{3,3}$")]
# Out:
#              sku                                               name  \
# 665    CRU0015-2  Crucial memory Mac 16GB (2x8GB) SO-DIMM DDR3 1...
# 792      APP0672                    Apple iPhone 5S 16GB Space Gray
# 797      APP0673                        Apple iPhone 5S 16GB Silver
# 827      PAC0339             NewerTech miniStack 4TB Hard Drive Mac
# 885      PAC0376       OWC Mercury Elite Pro Dual Thunderbolt + 8TB
# ...          ...                                                ...
# 19312    REP0424                       Input repair Headphones iPad
# 19313    REP0421                     iPad charging connector repair
# 19314    REP0416                           iPad front camera repair
# 19315    REP0413                            repair rear camera iPad
# 19316    REP0407                                iPad battery repair
#
#                                                     desc      price  \
# 665    RAM 16GB (2x8GB) 135V MacBook Pro iMac (2012/2...  1.639.792
# 792               New iPhone 5S 16G Libre (ME432Y / AB).  4.694.994
# 797                New Free iPhone 5S 16GB (ME433Y / A).  4.090.042
# 827                   External Box Hard Drive Mac + 4TB.  2.199.791
# 885    RAID outer box 35 inch SATA connection Thunder...  5.609.698
# ...                                                  ...        ...
# 19312  Repair service including parts and labor for iPad  6.999.003
# 19313  Repair service including parts and labor for iPad  6.999.003
# 19314  Repair service including parts and labor for iPad  6.999.003
# 19315  Repair service including parts and labor for iPad  6.999.003
# 19316  Repair service including parts and labor for iPad  6.999.003
#
#       promo_price  in_stock          type
# 665     1.629.894      True          1364
# 792     4.694.994     False             0
# 797     4.090.042     False             0
# 827     2.199.901     False      11935397
# 885     5.549.895     False      11935397
# ...           ...       ...           ...
# 19312       69.99     False  144000000000
# 19313       69.99     False  144000000000
# 19314       69.99     False  144000000000
# 19315       69.99     False  144000000000
# 19316       69.99     False  144000000000
#
# [377 rows x 7 columns]

# %%
products_df.loc[(products_df.loc[:, 'type'] > 1E+10) & (products_df.loc[:, 'price'].str.contains("^\d+\.\d{3,3}\.\d{3,3}$"))]
# Out:
#            sku                                               name  \
# 898    REP0156                        iPhone 5 GSM antenna repair
# 941    REP0185                       Home button repair iPad mini
# 943    REP0188                     Full Screen Repair iPad Mini 2
# 1057   MOP0057  Mophie Space Pack Battery Case (1700mAh) and S...
# 1058   MOP0058  Mophie Space Pack Battery Case (1700mAh) and S...
# ...        ...                                                ...
# 19312  REP0424                       Input repair Headphones iPad
# 19313  REP0421                     iPad charging connector repair
# 19314  REP0416                           iPad front camera repair
# 19315  REP0413                            repair rear camera iPad
# 19316  REP0407                                iPad battery repair
#
#                                                     desc       price  \
# 898    Repair service including parts and labor for i...  69.989.909
# 941    Repair service including parts and labor for i...  69.989.909
# 943    Repair service including parts and labor for i...   2.099.895
# 1057   Housing with battery and 16GB external storage...   1.329.911
# 1058   Housing with battery and 32GB external storage...   1.599.862
# ...                                                  ...         ...
# 19312  Repair service including parts and labor for iPad   6.999.003
# 19313  Repair service including parts and labor for iPad   6.999.003
# 19314  Repair service including parts and labor for iPad   6.999.003
# 19315  Repair service including parts and labor for iPad   6.999.003
# 19316  Repair service including parts and labor for iPad   6.999.003
#
#       promo_price  in_stock          type
# 898       699.899     False  144000000000
# 941       699.899     False  144000000000
# 943     2.099.895     False  144000000000
# 1057    1.329.911     False  549000000000
# 1058    1.599.862     False  549000000000
# ...           ...       ...           ...
# 19312       69.99     False  144000000000
# 19313       69.99     False  144000000000
# 19314       69.99     False  144000000000
# 19315       69.99     False  144000000000
# 19316       69.99     False  144000000000
#
# [107 rows x 7 columns]

# %%
products_df.loc[:, 'price'].str.count("\.").value_counts(normalize=True)
# Out:
# price
# 1    0.659879
# 0    0.304414
# 2    0.035708
# Name: proportion, dtype: float64

# %%
products_df.loc[products_df.loc[:, 'price'].str.contains("\d\.\d{3,3}\.\d{3,3}")]
# Out:
#              sku                                               name  \
# 665    CRU0015-2  Crucial memory Mac 16GB (2x8GB) SO-DIMM DDR3 1...
# 792      APP0672                    Apple iPhone 5S 16GB Space Gray
# 797      APP0673                        Apple iPhone 5S 16GB Silver
# 827      PAC0339             NewerTech miniStack 4TB Hard Drive Mac
# 885      PAC0376       OWC Mercury Elite Pro Dual Thunderbolt + 8TB
# ...          ...                                                ...
# 19312    REP0424                       Input repair Headphones iPad
# 19313    REP0421                     iPad charging connector repair
# 19314    REP0416                           iPad front camera repair
# 19315    REP0413                            repair rear camera iPad
# 19316    REP0407                                iPad battery repair
#
#                                                     desc      price  \
# 665    RAM 16GB (2x8GB) 135V MacBook Pro iMac (2012/2...  1.639.792
# 792               New iPhone 5S 16G Libre (ME432Y / AB).  4.694.994
# 797                New Free iPhone 5S 16GB (ME433Y / A).  4.090.042
# 827                   External Box Hard Drive Mac + 4TB.  2.199.791
# 885    RAID outer box 35 inch SATA connection Thunder...  5.609.698
# ...                                                  ...        ...
# 19312  Repair service including parts and labor for iPad  6.999.003
# 19313  Repair service including parts and labor for iPad  6.999.003
# 19314  Repair service including parts and labor for iPad  6.999.003
# 19315  Repair service including parts and labor for iPad  6.999.003
# 19316  Repair service including parts and labor for iPad  6.999.003
#
#       promo_price  in_stock          type
# 665     1.629.894      True          1364
# 792     4.694.994     False             0
# 797     4.090.042     False             0
# 827     2.199.901     False      11935397
# 885     5.549.895     False      11935397
# ...           ...       ...           ...
# 19312       69.99     False  144000000000
# 19313       69.99     False  144000000000
# 19314       69.99     False  144000000000
# 19315       69.99     False  144000000000
# 19316       69.99     False  144000000000
#
# [377 rows x 7 columns]

# %%
products_df.loc[products_df.loc[:, 'price'].str.contains("\d+\.\d{3,3}")]
# Out:
#            sku                                               name  \
# 362    REP0043                      Speaker lower repair iPhone 4
# 480    PIE0011                     Internal Battery for iPhone 3G
# 515    SEN0061  Sennheiser EZX 80 Handsfree iPhone iPad and iP...
# 518    SEV0026  Service installation RAM + HDD + SSD MacBook /...
# 525    SEV0024      Service installation RAM + HDD + SSD Mac mini
# ...        ...                                                ...
# 19312  REP0424                       Input repair Headphones iPad
# 19313  REP0421                     iPad charging connector repair
# 19314  REP0416                           iPad front camera repair
# 19315  REP0413                            repair rear camera iPad
# 19316  REP0407                                iPad battery repair
#
#                                                     desc      price  \
# 362    Repair service including parts and labor for i...    499.004
# 480          Replacement AC Adapter for Apple iPhone 3G.     98.978
# 515    IPhone bluetooth headset with microphone iPad ...    649.891
# 518    RAM + HDD installation + SSD in your MacBook /...    599.918
# 525    installation RAM HDD + SSD + on your Mac mini ...    599.918
# ...                                                  ...        ...
# 19312  Repair service including parts and labor for iPad  6.999.003
# 19313  Repair service including parts and labor for iPad  6.999.003
# 19314  Repair service including parts and labor for iPad  6.999.003
# 19315  Repair service including parts and labor for iPad  6.999.003
# 19316  Repair service including parts and labor for iPad  6.999.003
#
#       promo_price  in_stock          type
# 362       499.004     False  144000000000
# 480        98.978     False      21485407
# 515       649.891     False          5384
# 518       599.918     False      20642062
# 525       599.918     False      20642062
# ...           ...       ...           ...
# 19312       69.99     False  144000000000
# 19313       69.99     False  144000000000
# 19314       69.99     False  144000000000
# 19315       69.99     False  144000000000
# 19316       69.99     False  144000000000
#
# [542 rows x 7 columns]

# %%
import re

def deal_with_two_dots(price):
  dots = re.search("^(\d+)\.(\d{3,3})\.(\d)\d{2,2}", price)
  if dots:
    price = dots.group(1) + dots.group(2) + dots.group(3)
    return float(price)/100
  one_dot = re.search("^(\d+)\.(\d)\d{2,2}", price)
  if one_dot:
    price = one_dot.group(1) + one_dot.group(2)
    return float(price)/100
  return float(price)

products_df['price'] = products_df.agg(lambda x: deal_with_two_dots(x.loc['price']), axis=1)
# Out:
# <ipython-input-60-9a8ce25d8ff2>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_df['price'] = products_df.agg(lambda x: deal_with_two_dots(x.loc['price']), axis=1)

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.  59.00     589.996
# 2                                 mouse Apple USB cable.  59.00     569.898
# 3                  IPhone dock and USB Cable Apple iPod.  25.00     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
#        in_stock      type
# 0          True      8696
# 1         False  13855401
# 2         False      1387
# 3         False      1230
# 4          True      1364
# ...         ...       ...
# 19321      True     12282
# 19322      True      1392
# 19323      True      1392
# 19324     False      1392
# 19325      True      1392
#
# [10558 rows x 7 columns]

# %%
products_df.loc[:, 'promo_price'].str.contains('^\d+($|\.\d{2,2}$)').value_counts(normalize=True)
# Out:
# <ipython-input-62-cf2fbc711dbc>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   products_df.loc[:, 'promo_price'].str.contains('^\d+($|\.\d{2,2}$)').value_counts(normalize=True)
# promo_price
# False    0.923186
# True     0.076814
# Name: proportion, dtype: float64

# %%
products_df.loc[products_df.loc[:, 'price'] > 100]
# Out:
#            sku                                               name  \
# 50     APP0367  Apple Mini DisplayPort to DVI Adapter Mac dual...
# 51     APP0344          Apple Thunderbolt Display 27 "Monitor Mac
# 66     MAK0008  Maclocks theft case iPad 2 3 and 4 black with ...
# 67     MAK0007  Maclocks theft case iPad 2 3 and 4 transparent...
# 73     SYN0048                 Synology Pack 4 IP camera licenses
# ...        ...                                                ...
# 19316  REP0407                                iPad battery repair
# 19317  REP0403                             iPad LCD screen repair
# 19318  REP0402                           iPad touch screen repair
# 19319  KNO0032     Knomo MacBook Pro Beauchamp Backpack 14 "Black
# 19320  REP0076           repair Full screen iPad (1st generation)
#
#                                                     desc    price promo_price  \
# 50     Adapter Mini Display Port to DVI dual channel ...   119.00   1.119.976
# 51     Monitor Display 27-inch Apple Thunderbolt (MC9...  1149.00  10.449.923
# 66     Case antitheft iPad 2 3 and 4 polycarbonate ro...   120.00   1.199.957
# 67     Case antitheft iPad 2 3 and 4 polycarbonate ro...   120.00   1.079.961
# 73                    4 Pack licenses Mac and PC camera.   181.99     181.984
# ...                                                  ...      ...         ...
# 19316  Repair service including parts and labor for iPad   699.90       69.99
# 19317  Repair service including parts and labor for iPad   159.99   1.599.898
# 19318  Repair service including parts and labor for iPad   139.99   1.399.897
# 19319  Backpack thin nylon mesh internal compartment ...   179.00   1.699.905
# 19320  Repair service including parts and labor for iPad   149.99   1.499.795
#
#        in_stock          type
# 50        False          1325
# 51        False          1296
# 66        False      12635403
# 67        False      12635403
# 73        False          1404
# ...         ...           ...
# 19316     False  144000000000
# 19317     False  144000000000
# 19318     False  144000000000
# 19319      True          1392
# 19320     False  144000000000
#
# [5505 rows x 7 columns]

# %%
products_df['promo_price'] = products_df.agg(lambda x: deal_with_two_dots(x.loc['promo_price']), axis=1)
# Out:
# <ipython-input-64-5cec440321fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_df['promo_price'] = products_df.agg(lambda x: deal_with_two_dots(x.loc['promo_price']), axis=1)

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %%
products_df['price'] = products_df.loc[:, 'price'].astype(float)
products_df['promo_price'] = products_df.loc[:, 'promo_price'].astype(float)
products_df['in_stock'] = products_df.loc[:, 'in_stock'].astype(bool)
products_df['type'] = products_df.loc[:, 'type'].astype(int)
# Out:
# <ipython-input-66-9145fc61fa5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_df['price'] = products_df.loc[:, 'price'].astype(float)
# <ipython-input-66-9145fc61fa5a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_df['promo_price'] = products_df.loc[:, 'promo_price'].astype(float)
# <ipython-input-66-9145fc61fa5a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_df['in_stock'] = products_df.loc[:, 'in_stock'].astype(bool)
# <ipython-input-66-9145fc61fa5a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_df['type'] = products_df.loc[:, 'type'].astype(int)

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10558 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10558 non-null  object
#  1   name         10558 non-null  object
#  2   desc         10558 non-null  object
#  3   price        10558 non-null  float64
#  4   promo_price  10558 non-null  float64
#  5   in_stock     10558 non-null  bool
#  6   type         10558 non-null  int64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 587.7+ KB

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price  promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99        49.98
# 1              USB ultrathin keyboard Apple Mac Spanish.  59.00        58.99
# 2                                 mouse Apple USB cable.  59.00        56.98
# 3                  IPhone dock and USB Cable Apple iPod.  25.00        22.99
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99        31.99
# ...                                                  ...    ...          ...
# 19321  compact and portable stand vertically or horiz...  29.99        26.99
# 19322  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19323  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19324  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19325  Backpack with capacity of 14 liter compartment...  69.95        64.99
#
#        in_stock      type
# 0          True      8696
# 1         False  13855401
# 2         False      1387
# 3         False      1230
# 4          True      1364
# ...         ...       ...
# 19321      True     12282
# 19322      True      1392
# 19323      True      1392
# 19324     False      1392
# 19325      True      1392
#
# [10558 rows x 7 columns]

# %%
products_df.loc[products_df.loc[:, 'desc'].str.contains("iPad")]
# Out:
#            sku                                               name  \
# 11     SEN0021  Sennheiser CX 300-II Precision headphones iPho...
# 22     JMO0014                   Just Mobile Upstand iPad support
# 32     BEL0070        Music Receiver Belkin iPhone music receiver
# 36     APP0308  AV Cable Adapter Apple iPhone iPad and iPod white
# 39     JMO0026        Just Mobile Lazy Couch Support Mac and iPad
# ...        ...                                                ...
# 19315  REP0413                            repair rear camera iPad
# 19316  REP0407                                iPad battery repair
# 19317  REP0403                             iPad LCD screen repair
# 19318  REP0402                           iPad touch screen repair
# 19320  REP0076           repair Full screen iPad (1st generation)
#
#                                                     desc   price  promo_price  \
# 11        Headphones iPhone iPad iPad 2 iPad 3 and iPod.   49.99        44.98
# 22           Support Retina iPad and iPad mini aluminum.   49.95        39.99
# 32     Music Receiver iPhone iPad and iPod Touch for ...   49.99        29.98
# 36                IPhone iPad iPod adapter and AV cable.   45.00        35.99
# 39                        Mac and iPad small lift stand.   19.95        19.98
# ...                                                  ...     ...          ...
# 19315  Repair service including parts and labor for iPad  699.90        69.99
# 19316  Repair service including parts and labor for iPad  699.90        69.99
# 19317  Repair service including parts and labor for iPad  159.99       159.98
# 19318  Repair service including parts and labor for iPad  139.99       139.98
# 19320  Repair service including parts and labor for iPad  149.99       149.97
#
#        in_stock          type
# 11        False          5384
# 22        False          1216
# 32        False      11905404
# 36        False          1230
# 39        False          8696
# ...         ...           ...
# 19315     False  144000000000
# 19316     False  144000000000
# 19317     False  144000000000
# 19318     False  144000000000
# 19320     False  144000000000
#
# [1658 rows x 7 columns]

# %% [markdown]
# That looks like a plausible interpretation of promo_price; but there's no guarantee that this interpretation is correct. Furthermore promo_price without any information when it is in effect, is of very little value.
# Therefore promo_price should be completely dropped.
